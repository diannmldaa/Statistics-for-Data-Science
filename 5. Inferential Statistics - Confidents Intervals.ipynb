# %% [markdown]
# ## Inferential Statistics

# %% [markdown]
# Using Python to apply inferential statistics concepts including sampling distributions, confidence intervals, hypothesis testing, etc.

# %% [markdown]
# ### Confidence Intervals

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)

# %%
df = pd.read_csv('coffee_dataset.csv')
df.head()
# Out:
#    user_id   age  drinks_coffee     height
# 0     4509   <21          False  64.538179
# 1     1864  >=21           True  65.824249
# 2     2060   <21          False  71.319854
# 3     7875  >=21           True  68.569404
# 4     6254   <21           True  64.020226

# %%
df.shape
# Out:
# (2974, 4)

# %%
coffee_full = pd.read_csv('coffee_dataset.csv')
coffee_sample = coffee_full.sample(200)

# %%
coffee_sample
# Out:
#       user_id   age  drinks_coffee     height
# 2402     2874   <21           True  64.357154
# 2864     3670  >=21           True  66.859636
# 2167     7441   <21          False  66.659561
# 507      2781  >=21           True  70.166241
# 1817     2875  >=21           True  71.369120
# ...       ...   ...            ...        ...
# 1187     6237   <21          False  62.493744
# 463      1857   <21          False  66.476106
# 1195     6397   <21          False  64.555794
# 1080     4065   <21          False  66.842149
# 1422     3971   <21          False  61.891849
#
# [200 rows x 4 columns]

# %%
# Explore dataset
coffee_sample.head()
coffee_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 2402 to 1422
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   user_id        200 non-null    int64
#  1   age            200 non-null    object
#  2   drinks_coffee  200 non-null    bool
#  3   height         200 non-null    float64
# dtypes: bool(1), float64(1), int64(1), object(1)
# memory usage: 6.4+ KB

# %%
# Proportion of coffee drinkers in sample
mean_drinker = coffee_sample['drinks_coffee'].mean()
mean_non_drinker = 1 - mean_drinker

# %%
print(mean_drinker)
print(mean_non_drinker)
# Out:
# 0.595
# 0.405

# %%
# Average height of coffee drinkers 
drinker_height = coffee_sample[coffee_sample['drinks_coffee']]['height'].mean()
drinker_height
# Out:
# 68.11962990858618

# %%
# Average height of coffee non drinkers 
non_drinker_height = coffee_sample[~coffee_sample['drinks_coffee']]['height'].mean()
non_drinker_height
# Out:
# 66.78492279927877

# %%
# Bootstrap sample of 200 draws
bootsamp = coffee_sample.sample(200, replace=True)
bootsamp['drinks_coffee'].mean()
# Out:
# 0.605

# %%
# Bootstrap sample of 10,000 times
boot_means = []
for _ in range(10000):
    bootsamp = coffee_sample.sample(200, replace=True) #kalau replace=False chart tidak muncul
    mean = bootsamp[bootsamp['drinks_coffee'] == False]['height'].mean()
    boot_means.append(mean)
    
plt.hist(boot_means, color='salmon')
# Out:
# (array([3.000e+00, 4.900e+01, 3.720e+02, 1.608e+03, 3.122e+03, 2.994e+03,
#         1.436e+03, 3.630e+02, 4.600e+01, 7.000e+00]),
#  array([65.0634378 , 65.41077637, 65.75811493, 66.1054535 , 66.45279207,
#         66.80013064, 67.14746921, 67.49480777, 67.84214634, 68.18948491,
#         68.53682348]),
#  <BarContainer object of 10 artists>)

# %%
# Obtain 95% confidence interval
np.percentile(boot_means, 2.5), np.percentile(boot_means, 97.5)
# Out:
# (65.99291328157521, 67.58402738281573)

# %%
coffee_full[coffee_full['drinks_coffee'] == False]['height'].mean()
# Out:
# 66.44340776214703

# %% [markdown]
# Task

# %%
# Explore dataset
coffee_sample.head()
coffee_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 2402 to 1422
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   user_id        200 non-null    int64
#  1   age            200 non-null    object
#  2   drinks_coffee  200 non-null    bool
#  3   height         200 non-null    float64
# dtypes: bool(1), float64(1), int64(1), object(1)
# memory usage: 6.4+ KB

# %%
# Proportion of coffee drinkers in sample
mean_drinker = coffee_sample['drinks_coffee'].mean()
mean_non_drinker = 1 - mean_drinker

print(mean_drinker)
print(mean_non_drinker)

# %%
# Average height of coffee drinkers 
drinker_height = coffee_sample[coffee_sample['drinks_coffee']]['height'].mean()
drinker_height

# %%
# Average height of coffee non drinkers 
non_drinker_height = coffee_sample[~coffee_sample['drinks_coffee']]['height'].mean()
non_drinker_height

# %%
# Bootstrap sample of 200 draws
bootsamp = coffee_sample.sample(200, replace=True)
bootsamp['drinks_coffee'].mean()

# %%
# Bootstrap sample of 10,000 times
boot_means = []
for _ in range(10000):
    bootsamp = coffee_sample.sample(200, replace=True)
    mean = bootsamp[bootsamp['drinks_coffee'] == False]['height'].mean()
    boot_means.append(mean)
    
plt.hist(boot_means, color='salmon')

# %%
# Obtain 95% confidence interval
np.percentile(boot_means, 2.5), np.percentile(boot_means, 97.5)

# %%
mata_dadu = pd.Series([1,2,3,4,5,6])
boot_means1 = []
for _ in range(10):
    bootsamp1 = mata_dadu.sample(4, replace=True)
    mean = bootsamp1.mean()
    boot_means1.append(bootsamp)

boot_means1
# Out:
# [      user_id   age  drinks_coffee     height
#  178      5041  >=21           True  69.996510
#  2079     3000   <21          False  69.464279
#  2050     8144  >=21           True  68.801947
#  2320     7755  >=21           True  68.194103,
#        user_id   age  drinks_coffee     height
#  178      5041  >=21           True  69.996510
#  2079     3000   <21          False  69.464279
#  2050     8144  >=21           True  68.801947
#  2320     7755  >=21           True  68.194103,
#        user_id   age  drinks_coffee     height
#  178      5041  >=21           True  69.996510
#  2079     3000   <21          False  69.464279
#  2050     8144  >=21           True  68.801947
#  2320     7755  >=21           True  68.194103,
#        user_id   age  drinks_coffee     height
#  178      5041  >=21           True  69.996510
#  2079     3000   <21          False  69.464279
#  2050     8144  >=21           True  68.801947
#  2320     7755  >=21           True  68.194103,
# ...

# %%
mata_dadu = [1,2,3,4,5,6]
for _ in range(10):
    bootsamp = coffee_sample.sample(4, replace=False)
    #mean = bootsamp[bootsamp]['height'].mean()
    boot_means.append(bootsamp)

boot_means
# Out:
# [66.90113706858966,
#  66.86050104804973,
#  66.58284911521685,
#  66.92197330823662,
#  66.87036200102445,
#  67.44359326562903,
#  66.59696823234033,
#  66.88170855265251,
#  66.73386060192688,
#  66.79557436761976,
#  67.12207497127405,
#  66.83745349480705,
#  66.0316405398306,
#  66.93594767692785,
#  67.06855650196137,
#  66.71727029656226,
#  67.24432012719994,
#  66.84791181284344,
#  66.49575400132316,
#  66.6300744259605,
#  67.05935496312743,
#  66.95680653879631,
#  66.226613019447,
#  66.43880974743188,
#  66.61191494312003,
#  66.64167215419887,
#  67.49662815429011,
#  66.57126307954397,
#  67.00541922552372,
#  66.9901094407212,
#  67.10553892585008,
#  66.40006839096083,
#  66.41830853028642,
#  66.51044842713512,
#  66.71980682534901,
#  66.513903744823,
#  67.12769425718585,
#  67.53298109310406,
#  67.82100879340007,
#  66.2700988894029,
#  66.87357412369762,
#  66.56527680554464,
#  66.90326588911819,
#  66.59234135513123,
#  66.77904918117646,
# ...
