# %% [markdown]
# ### Statistics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ![Screenshot%202022-10-17%20075211.png](attachment:Screenshot%202022-10-17%20075211.png)

# %%
df = pd.read_csv('Titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
len(df)
# Out:
# 891

# %% [markdown]
# Task

# %%
# Numerical 
# 1. Diskrit
diskrit = df['PassengerId', 'SibSp', 'Parch', 'Fare']
# 2. Kontinu
kontinu = df['Fare', 'Age']

# %%
# Categorical 
# 1. Ordinal
ordinal = df['Pclass']
# 2. Kategorical
kategorikal = df['Survived', 'Sex', 'Name', 'Ticket', 'Cabin', 'Embarked']

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.mode()
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 0              1       0.0     3.0                    Abbing, Mr. Anthony
# 1              2       NaN     NaN            Abbott, Mr. Rossmore Edward
# 2              3       NaN     NaN       Abbott, Mrs. Stanton (Rosa Hunt)
# 3              4       NaN     NaN                    Abelson, Mr. Samuel
# 4              5       NaN     NaN  Abelson, Mrs. Samuel (Hannah Wizosky)
# ..           ...       ...     ...                                    ...
# 886          887       NaN     NaN                de Mulder, Mr. Theodore
# 887          888       NaN     NaN              de Pelsmaeker, Mr. Alfons
# 888          889       NaN     NaN              del Carlo, Mr. Sebastiano
# 889          890       NaN     NaN        van Billiard, Mr. Austin Blyler
# 890          891       NaN     NaN            van Melkebeke, Mr. Philemon
#
#       Sex   Age  SibSp  Parch    Ticket  Fare        Cabin Embarked
# ...

# %% [markdown]
# ### Probability

# %% [markdown]
# P = n(A)/n(S)

# %%
# Banyak kejadian dan ruang sample

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df[(df['Sex'] == 'female') & (df['Survived'] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df['Sex'] == 'female') & (df['Survived'] == 1)].shape
# Out:
# (233, 12)

# %%
# Passenger laki-laki berusia lebih dari 30 tahun
df[(df['Sex'] == 'male') & (df['Age'] > 30)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 4              5         0       3              Allen, Mr. William Henry
# 6              7         0       1               McCarthy, Mr. Timothy J
# 13            14         0       3           Andersson, Mr. Anders Johan
# 20            21         0       2                  Fynney, Mr. Joseph J
# 21            22         1       2                 Beesley, Mr. Lawrence
# ..           ...       ...     ...                                   ...
# 867          868         0       1  Roebling, Mr. Washington Augustus II
# 872          873         0       1              Carlsson, Mr. Frans Olof
# 873          874         0       3           Vander Cruyssen, Mr. Victor
# 881          882         0       3                    Markun, Mr. Johann
# 890          891         0       3                   Dooley, Mr. Patrick
#
#       Sex   Age  SibSp  Parch    Ticket     Fare        Cabin Embarked
# ...

# %%
df[(df['Sex'] == 'male') & (df['Age'] > 30)].shape
# Out:
# (202, 12)

# %% [markdown]
# Task

# %%
# Jumlah penumpang yg selamat dengan usia di bawah 20 tahun
df[(df['Survived'] == 1) & (df['Age'] < 20)].shape[0]
# Out:
# 79

# %%
# Jumlah penumpang perempuan yg membawa saudara lebih dari atau sama dengan 2
df[(df['Sex'] == 'female') & (df['SibSp'] >= 2)].shape[0]
# Out:
# 34

# %%
# Jumlah penumpang di kabin C123 yg selamat dengan usia di atas 10 tahun
df[(df['Cabin'] == 'C123') & (df['Survived'] == 1) & (df['Age'] > 10)].shape[0]
# Out:
# 1

# %% [markdown]
# Group by (tambahan aja)

# %%
df.groupby(['Pclass']).count()
# Out:
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass
# 1               216       216   216  216  186    216    216     216   216
# 2               184       184   184  184  173    184    184     184   184
# 3               491       491   491  491  355    491    491     491   491
#
#         Cabin  Embarked
# Pclass
# 1         176       214
# 2          16       184
# 3          12       491

# %%
df[(df['Survived'] == 1)].groupby(['Pclass']).count()
# Out:
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass
# 1               136       136   136  136  122    136    136     136   136
# 2                87        87    87   87   83     87     87      87    87
# 3               119       119   119  119   85    119    119     119   119
#
#         Cabin  Embarked
# Pclass
# 1         117       134
# 2          13        87
# 3           6       119

# %%
# Passenger perempuan atau passenger dari kelas 1
df['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df[(df['Sex'] == 'female') | (df['Survived'] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Passenger laki-laki selain dari kelas 3
df[(df['Sex'] == 'male') & (df['Pclass'] != 3)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 6              7         0       1               McCarthy, Mr. Timothy J
# 17            18         1       2          Williams, Mr. Charles Eugene
# 20            21         0       2                  Fynney, Mr. Joseph J
# 21            22         1       2                 Beesley, Mr. Lawrence
# 23            24         1       1          Sloper, Mr. William Thompson
# ..           ...       ...     ...                                   ...
# 867          868         0       1  Roebling, Mr. Washington Augustus II
# 872          873         0       1              Carlsson, Mr. Frans Olof
# 883          884         0       2         Banfield, Mr. Frederick James
# 886          887         0       2                 Montvila, Rev. Juozas
# 889          890         1       1                 Behr, Mr. Karl Howell
#
#       Sex   Age  SibSp  Parch            Ticket     Fare        Cabin Embarked
# ...

# %%
# Passenger berusia di bawah 10 tahun selain passenger perempuan
df[(df['Age'] < 10) & (~(df['Sex'] == 'male'))]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 24            25         0       3             Palsson, Miss. Torborg Danira
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# 58            59         1       2              West, Miss. Constance Mirium
# 119          120         0       3         Andersson, Miss. Ellis Anna Maria
# 147          148         0       3          Ford, Miss. Robina Maggie "Ruby"
# 172          173         1       3              Johnson, Miss. Eleanor Ileen
# 184          185         1       3       Kink-Heilmann, Miss. Luise Gretchen
# 205          206         0       3                Strom, Miss. Telma Matilda
# 233          234         1       3            Asplund, Miss. Lillian Gertrud
# 237          238         1       2          Collyer, Miss. Marjorie "Lottie"
# ...

# %% [markdown]
# Task

# %%
# atau

# Jumlah penumpang yg selamat atau penumpang dengan usia di bawah 20 tahun
df[(df['Survived'] == 1) | (df['Age'] < 20)].shape[0]
# Out:
# 427

# %%
# !=

# Jumlah penumpang yang bukan perempuan yg membawa saudara lebih dari atau sama dengan 2
df[(df['Sex'] != 'female') & (df['SibSp'] >= 2)].shape[0]
# Out:
# 40

# %%
# ~

# Jumlah penumpang di kabin selain C123 yg selamat dengan usia di atas 10 tahun
df[(~(df['Cabin'] == 'C123')) & (df['Survived'] == 1) & (df['Age'] > 10)].shape[0]
# Out:
# 251

# %%
# gabungan atau, !=, dan ~

# Jumlah penumpang di kabin selain C123 yg tidak selamat atau usia di atas 10 tahun
df[(~(df['Cabin'] == 'C123')) & ((df['Survived'] != 1) | (df['Age'] > 10))].shape[0]
# Out:
# 799

# %% [raw]
# --------

# %%
# Peluang passenger perempuan yang hidup

# %%
# Female and survived

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df[(df['Sex'] == 'female') & (df['Survived'] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df['Sex'] == 'female') & (df['Survived'] == 1)].shape
# Out:
# (233, 12)

# %%
df[(df['Sex'] == 'female') & (df['Survived'] == 1)].shape[0]
# Out:
# 233

# %%
df['PassengerId'].shape[0]
# Out:
# 891

# %%
# Peluang passenger perempuan yang hidup

na = df[(df['Sex'] == 'female') & (df['Survived'] == 1)].shape[0]
ns = df['PassengerId'].shape[0]

p = na/ns
print(p)
# Out:
# 0.2615039281705948

# %%
# Peluang laki-laki yang hidup di antara semua passenger yang hidup

na = df[(df['Sex'] == 'male') & (df['Survived'] == 1)].shape[0]
ns = df[(df['Survived'] == 1)].shape[0]==

p = na/ns
print(p)
# Out:
# 0.31871345029239767

# %%
# Laki-lakki yang hidup

# %%
df[(df['Sex'] == 'male') & (df['Survived'] == 1)]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 17            18         1       2     Williams, Mr. Charles Eugene  male
# 21            22         1       2            Beesley, Mr. Lawrence  male
# 23            24         1       1     Sloper, Mr. William Thompson  male
# 36            37         1       3                 Mamee, Mr. Hanna  male
# 55            56         1       1                Woolner, Mr. Hugh  male
# ..           ...       ...     ...                              ...   ...
# 838          839         1       3                  Chip, Mr. Chang  male
# 839          840         1       1             Marechal, Mr. Pierre  male
# 857          858         1       1           Daly, Mr. Peter Denis   male
# 869          870         1       3  Johnson, Master. Harold Theodor  male
# 889          890         1       1            Behr, Mr. Karl Howell  male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# ...

# %%
df[(df['Sex'] == 'male') & (df['Survived'] == 1)].shape
# Out:
# (109, 12)

# %%
df[(df['Sex'] == 'male') & (df['Survived'] == 1)].shape[0]
# Out:
# 109

# %%
# Peluang passenger laki-laki yang hidup

na = df[(df['Sex'] == 'male') & (df['Survived'] == 1)].shape[0]
ns = df['PassengerId'].shape[0]

p = na/ns
print(p)
# Out:
# 0.122334455667789

# %% [markdown]
# Task

# %%
# Peluang passenger berusia lebih dari 50 tahun yang hidup

na = df[(df['Age'] > 50) & (df['Survived'] == 1)].shape[0]
ns = df['PassengerId'].shape[0]

p = na/ns
print(p)
# Out:
# 0.024691358024691357

# %%
# Peluang passenger berusia lebih dari 50 tahun yang hidup yang bukan perempuan

na = df[(df['Age'] > 50) & (df['Survived'] == 1) & (df['Sex'] != 'female')].shape[0]
ns = df['PassengerId'].shape[0]

p = na/ns
print(p)
# Out:
# 0.006734006734006734

# %%
# Peluang passenger di kelas 1 yang hidup dari semua penumpang di kelas 1

na = df[(df['Pclass'] == 1) & (df['Survived'] == 1)].shape[0]
ns = df[(df['Pclass'] == 1)].shape[0]

p = na/ns
print(p)
# Out:
# 0.6296296296296297

# %%
a = df.groupby(['Pclass']).agg({'PassengerId' : 'count'})
a = a.reset_index()
a.columns = ['Class', 'Total Passenger']
a
# Out:
#    Class  Total Passenger
# 0      1              216
# 1      2              184
# 2      3              491

# %%
a['Peluang'] = a['Total Passenger']/(a['Total Passenger'].sum())
a
# Out:
#    Class  Total Passenger   Peluang
# 0      1              216  0.242424
# 1      2              184  0.206510
# 2      3              491  0.551066
