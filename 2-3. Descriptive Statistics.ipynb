# %% [markdown]
# ## Descriptive Statistics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Titanic.csv')

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# ### Measure of Central Tendency

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['Age'].median()
# Out:
# 28.0

# %%
df['Age'].mode().values[0]
# Out:
# 24.0

# %% [markdown]
# Task

# %%
# Mean, median, modus

x = df['Fare'].mean()
y = df['Fare'].median()
z = df['Fare'].mode().values[0]

print('Mean:', x)
print('Median:', y)
print('Modus:', z)
# Out:
# Mean: 32.2042079685746
# Median: 14.4542
# Modus: 8.05

# %%
# Manual

usia = [21,20,21,20,21]

rata2 = (20+21+20+21+20)/5
print(rata2)
# Out:
# 20.4

# %% [markdown]
# ### Range
#
# Calculate the difference by substracting the smallest from the largest

# %%
df_age_notnull = df['Age'][df['Age'].notnull()]

# %%
print(df_age_notnull)
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 714, dtype: float64

# %%
df_age_notnull.max()
# Out:
# 80.0

# %%
df_age_notnull.min()
# Out:
# 0.42

# %%
range_age = np.ptp(df_age_notnull)
print(range_age)
# Out:
# 79.58

# %% [markdown]
# Task

# %%
# Range menggunakan numpy

df_fare_notnull = df['Fare'][df['Fare'].notnull()]
range_fare = np.ptp(df_fare_notnull)
print(range_fare)
# Out:
# 512.3292

# %%
# Range menggunakan cara manual

a = df_fare_notnull.max()
b = df_fare_notnull.min()
c = a - b
print(c)
# Out:
# 512.3292

# %% [markdown]
# ### Variance

# %%
import statistics

# %%
variance_age = statistics.variance(df_age_notnull)
print(variance_age)
# Out:
# 211.01912474630805

# %% [markdown]
# ### Standard Deviation

# %%
import statistics

# %%
stadev_age = statistics.stdev(df_age_notnull)
print(stadev_age)
# Out:
# 14.526497332334042

# %% [markdown]
# Task

# %% [markdown]
# - Sampel

# %% [markdown]
# ![lat2.png](attachment:lat2.png)

# %%
# Variance

usia = [21,20,21,20,21]

variance_usia = statistics.variance(usia)
print('Variance:', variance_usia)
# Out:
# Variance: 0.3

# %%
# Standard Deviation

usia = [21,20,21,20,21]

std_usia = statistics.stdev(usia)
print('Standard Deviation:', std_usia)
# Out:
# Standard Deviation: 0.5477225575051661

# %% [markdown]
# - Populasi

# %% [markdown]
# ![lat3.png](attachment:lat3.png)

# %%
# Variance

usia = [21,20,21,20,21]

pvar_usia = statistics.pvariance(usia)
print('Variance:', pvar_usia)
# Out:
# Variance: 0.24

# %%
# Standard Deviation

usia = [21,20,21,20,21]

pstd_usia = statistics.pstdev(usia)
print('Standard Deviation:', pstd_usia)
# Out:
# Standard Deviation: 0.4898979485566356

# %% [markdown]
# ### Quantile

# %% [markdown]
# ![q.jpg](attachment:q.jpg)

# %% [markdown]
# - Q0 is the smallest value in the data.
# - Q1 is the value separating the first quarter from the second quarter of the data.
# - Q2 is the middle value (median), separating the bottom from the top half.
# - Q3 is the value separating the third quarter from the fourth quarter
# - Q4 is the largest value in the data

# %%
quantile_age = np.quantile(df_age_notnull, [0, 0.25, 0.5,0.75,1]) 
print(quantile_age)
# Out:
# [ 0.42  20.125 28.    38.    80.   ]

# %% [markdown]
# Task

# %%
# Quantile menggunakan numpy

q_fare = np.quantile(df_fare_notnull, [0, 0.25, 0.5,0.75,1])
print(q_fare)
# Out:
# [  0.       7.9104  14.4542  31.     512.3292]

# %%
# Quantile menggunakan cara manual

usia = [21,20,21,20,21]

q_usia = np.quantile(usia, [0, 0.25, 0.5,0.75,1])
print(q_usia)
# Out:
# [20. 20. 21. 21. 21.]

# %% [markdown]
# ### Skewness

# %% [markdown]
# ![skew.png](attachment:skew.png)

# %%
df['Age'].plot(kind='hist', color="#212529");

# %% [markdown]
# Task

# %%
df['Fare'].plot(kind='hist', color="#212529");

# %%
plt.figure(figsize=(8,4))
plt.title('Fare Distribution Graph', 
          fontweight='bold', fontsize = 16, color='#212529')

sns.distplot(df["Fare"], color="#212529", hist=True);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(8,4))
plt.title('Fare Distribution Graph', 
          fontweight='bold', fontsize = 16, color='#450920')

sns.kdeplot(df['Fare'], color="#212529", shade=True);

# %% [markdown]
# ### Correlation Coefficient

# %% [markdown]
# Correlation doesnt imply causation

# %% [markdown]
# A number between -1 and 1 that explains:
# 1. The direction of the trend
# 2. Quality of straight line fit

# %% [markdown]
# ![cc.png](attachment:cc.png)

# %%
plt.figure(figsize=(8,4))
sns.heatmap(df.corr(), annot=True);

# %%
df[['Age', 'Survived']].corr()
# Out:
#                Age  Survived
# Age       1.000000 -0.077221
# Survived -0.077221  1.000000

# %% [markdown]
# Task

# %%
nama_usia = pd.read_csv('nama_usia.csv')
nama_usia
# Out:
#       Nama  Usia
# 0     Axel    20
# 1     Yogi    21
# 2     Dian    20
# 3  Yesaya     21
# 4      Dwi    21

# %%
plt.figure(figsize=(8,4))
sns.heatmap(nama_usia.corr(), annot=True);

# %%
nama_usia[['Nama', 'Usia']].corr()
# Out:
#       Usia
# Usia   1.0

# %% [markdown]
# Task 2 [TB vs BB]

# %%
cc = pd.read_csv('cc.csv')
cc
# Out:
#       Nama  Usia   TB  BB
# 0     Axel    20  180  60
# 1     Yogi    21  182  66
# 2     Dian    20  170  58
# 3  Yesaya     21  178  70
# 4      Dwi    21  172  50

# %% [markdown]
# Hitungan menggunakan python:

# %%
plt.figure(figsize=(8,4))
sns.heatmap(cc.corr(), annot=True);

# %%
cc[['Usia', 'TB', 'BB']].corr()
# Out:
#           Usia        TB        BB
# Usia  1.000000  0.246871  0.213561
# TB    0.246871  1.000000  0.667811
# BB    0.213561  0.667811  1.000000

# %% [markdown]
# Hitungan manual:

# %% [markdown]
# ![cc%20kel.png](attachment:cc%20kel.png)

# %% [markdown]
# Task 3 [Usia vs TB]

# %%
cc[['Usia', 'TB']].corr()
# Out:
#           Usia        TB
# Usia  1.000000  0.246871
# TB    0.246871  1.000000

# %% [markdown]
# ![usia%20tb.png](attachment:usia%20tb.png)
